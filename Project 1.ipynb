# %% [markdown]
# # English Dictionary app

# %%
import pickle

def saveDictionary(tmp_dict):
    
    try:
        
        with open('words.txt','wb') as dictionary:
            
            pickle.dump(tmp_dict,dictionary)
            
            dictionary=open('words.txt','wb')
            
            pickle.dump(tmp_dict,dictionary)
            
            dictionary.close()
            
            print("SUCCESS:writing to dictionary words.txt")
            
    except Exception as e :
        
        print(f"ERROR:{e}")
        
        
def getDictionary():
    
    try:
        
        with open('word.txt','rb') as dictionary:
            
            tmp_dict=pickle.load(dictionaty)
            
            print("SUCCESS:reading from dicionary word.txt")
            
            return tmp_dict
        
    except Exception as e:
        
        print(f"ERROR:{e}")
        
        
def addNewWord():
    
    print("________")
    print("NEW WORD ADDER:")
    print("________")
    print("Enter a word to add")
    word=input("eneter a word")
    
    print(f"Enter a meaning of {word} to add")
    
    meaning=input("Enter the meaning of the word")
    dictionary=getDictionary()
    dictionary[word]=meaning
    saveDictionary(dictionary)
    
    main_menu()
    
def findMeaning():
    
    print("______")
    print("WORD FINDER")
    print("______")
    print("Enter a word to find")
    
    word=input("enter a word")
    dictionary=getDictionary()
    
    if word in dictionary:
        
        print(f"Found Entry:[{word}{dictionary[word]}]")
        
    else:
        
        print("ERROR: The word doesn't exist!")
        
        findMeaning()
        
        main_menu()
        
        
def updateWord():
    
    print("______")
    print("WORD UPDATER:")
    print("______")
    print("Enter an old word to edit")
    word=input("Enter a word ")
    
    dictionary=getDictionary()
    
    if word in dictionary:
        
        print(f"Enter a new meaning to edit [{word}:{dictionary[word]}] to:")
        
        new_meaning=input("enter a meaning of the word")
        dictionary[word]=new_meaning
        saveDictionary(dictionary)
        
        print(f"SUCCESS:Update to [{word}:{dictionary[word]}]")
        
    else:
        
        print("ERROR:The word doesn't exixt! impossible to update!")
        
        updateWord()
        
        main_menu()
        
        
def main_menu():
    
    print("______")
    print("ENGLISH DICTIONARY APP")
    print("______")
    print("1.Add a new word")
    print("2.Find the meaning")
    print("3.Update a word ")
    print("4.Exit")
    print("______")
    
    
    n=int(input("enter the function you want"))
    
    if n==1:
        
        addNewWord()
        
    elif n==2:
        
        findMeaning()
        
    elif n==3:
        
        updateWord()
        
    elif n==4:
        
        exit()
        
    else:
        
        print("ERROR: Please Enter a digit according to Menu.")
        
        main_menu()
        
        
    
main_menu()
    
print(getDictionary())
dictionary={}
    
saveDictionary(dictionary)
# Out:
# ______
# ENGLISH DICTIONARY APP
# ______
# 1.Add a new word
# 2.Find the meaning
# 3.Update a word
# 4.Exit
# ______
# enter the function you want1
# ________
# NEW WORD ADDER:
# ________
# Enter a word to add
# eneter a wordhelp
# Enter a meaning of help to add
# Enter the meaning of the wordhelping
# ERROR:[Errno 2] No such file or directory: 'word.txt'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 142>()
#     136         print("ERROR: Please Enter a digit according to Menu.")
#     138         main_menu()
# --> 142 main_menu()
#     144 print(getDictionary())
#     145 dictionary={}
#
# Input In [6], in main_menu()
#     116 n=int(input("enter the function you want"))
#     118 if n==1:
# --> 120     addNewWord()
#     122 elif n==2:
#     124     findMeaning()
#
# Input In [6], in addNewWord()
#      45 meaning=input("Enter the meaning of the word")
#      46 dictionary=getDictionary()
# ---> 47 dictionary[word]=meaning
#      48 saveDictionary(dictionary)
#      50 main_menu()
#
# TypeError: 'NoneType' object does not support item assignment

# %% [markdown]
# # Library book management

# %%
from tkinter import *
import sqlite3
import tkinter.ttk as ttk
import tkinter.messagebox as tkMessageBox

root=Tk()
root.title('....Library book management....')

def Database():
    
    global conn,cursor
    conn=sqlite3.connect('simple.db')
    cursor=conn.cursor()
    cursor.execute("CREATE TABLE IF NOT EXISTS book(Booktitle TEXT, Author TEXT, Year INTEGER, ISBN INTEGER )")
    
def Add():
    
    if BOOKTITLE.get()=='' or AUTHOR.get()=='' or YEAR.get()=='' or ISBN.get()=='':
        
        txt_result.config(text="Please enter all field",fg="red")
        
    else:
        
        Database()
        cursor.execute("INSERT IN TO book(Booktitle,Author,Year,ISBN) VALUES (?,?,?,?,)",str(BOOKTITLE.get()),str(AUTHOR.get()),str(YEAR.get()),str(ISBN.get()))
        
        conn.commit()
        BOOKTITLE.set("")
        AUTHOR.set("")
        YEAR.set("")
        ISBN.set("")
        cursor.close()
        conn.close()
        
        txt_result.config(text="Record Inserted!", fg="green")
        
        
def Display():
    
    tree.delete(* tree.get_children)
    Database()
    cursor.execute("SELECT * FROM book ORDER BY Author ASC")
    fetch=cursor.fetchall()
    
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
        
    cursor.close()
    
    txt_result.config(text="successfully fetched data ",fg="black")
    
    
def Exit():
    
    result=tkMessageBox.askquestion('Do you want to exit ? (y/n)',icon='warning')
    
    if result=='yes':
        
        root.destroy()
        
        exit()
        
# variable declaration

BOOKTITLE=StringVar()
AUTHOR=StringVar()
YEAR=StringVar()
ISBN=StringVar()

#frame

Top=Frame(root,width=900,height=50,bd=8,relief='raise')
Top.pack(side=TOP)

Left=Frame(root,width=300,height=500,bd=8,relief='raise')
Left.pack(side=LEFT)

Right=Frame(root,width=600,height=500,bd=8,relief='raise')
Right.pack(side=RIGHT)

Forms=Frame(Left,width=300,height=450)
Forms.pack(side=TOP)

Buttons=Frame(Left,width=300,height=100,bd=8,relief='raise')
Buttons.pack(side=BOTTOM)


# labels

txt_title=Label(Top,width=900,font=('arial',24),text='....Library Book Management....')
txt_title.pack()

txt_Booktitle=Label(Forms,text='Booktitle:',font=('arial',16),bd=15)
txt_Booktitle.grid(row=0,stick="e")

txt_Author=Label(Forms,text='Author:',font=('arial',16),bd=15)
txt_Author.grid(row=1,stick="e")

txt_Year=Label(Forms,text='Year:',font=('arial',16),bd=15)
txt_Year.grid(row=2,stick="e")

txt_ISBN=Label(Forms,text='ISBN:',font=('arial',16),bd=15)
txt_ISBN.grid(row=3,stick="e")

txt_result=Label(Buttons)
txt_result.pack(side=TOP)


# entry 

Booktitle=Entry(Forms,textvariable=BOOKTITLE,width=30)
Booktitle.grid(row=0,column=1)

Author=Entry(Forms,textvariable=AUTHOR,width=30)
Author.grid(row=1,column=1)

Year=Entry(Forms,textvariable=YEAR,width=30)
Year.grid(row=2,column=1)

ISBN=Entry(Forms,textvariable=ISBN,width=30)
ISBN.grid(row=3,column=1)


# button 


btn_Display=Button(Buttons,width=10,text='Display',command=Display)
btn_Display.pack(side=LEFT)

btn_search=Button(Buttons,width=10,text='Search',command=DISABLED)
btn_search.pack(side=LEFT)

btn_Add=Button(Buttons,width=10,text='Add',command=Add)
btn_Add.pack(side=LEFT)

btn_issue=Button(Buttons,width=10,text='Issue',command=DISABLED)
btn_issue.pack(side=LEFT)

btn_Delete=Button(Buttons,width=10,text='Delete',command=DISABLED)
btn_Delete.pack(side=LEFT)

btn_exit=Button(Buttons,width=10,text='Exit',command=Exit)
btn_exit.pack(side=LEFT)



# list 

scrollbary=Scrollbar(Right,orient=VERTICAL)
scrollbarx=Scrollbar(Right,orient=HORIZONTAL)

tree=ttk.Treeview(Right,column=("Booktitle","Author","Year","ISBN"))

scrollbary.config(command=tree.yview)
scrollbary.pack(side=RIGHT,fill=Y)

scrollbarx.config(command=tree.xview)
scrollbarx.pack(side=BOTTOM,fill=X)

tree.heading('Booktitle',text="Booktitle",anchor=W)
tree.heading('Author',text="Author",anchor=W)
tree.heading('Year',text="Year",anchor=W)
tree.heading('ISBN',text="ISBN",anchor=W)


tree.column("#0",stretch=NO,minwidth=0,width=0)
tree.column("#1",stretch=NO,minwidth=0,width=80)
tree.column("#2",stretch=NO,minwidth=0,width=120)
tree.column("#3",stretch=NO,minwidth=0,width=80)
tree.pack()

if __name__=='__main__':
    
    root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Ragu.M\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Ragu.M\AppData\Local\Temp\ipykernel_12032\1970329802.py", line 25, in Add
#     cursor.execute("INSERT IN TO book(Booktitle,Author,Year,ISBN) VALUES (?,?,?,?,)",str(BOOKTITLE.get()),str(AUTHOR.get()),str(YEAR.get()),str(ISBN.get()))
# TypeError: function takes at most 2 arguments (5 given)
